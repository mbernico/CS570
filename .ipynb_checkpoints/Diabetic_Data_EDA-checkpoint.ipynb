# %%
import pandas as pd
# %matplotlib inline

# %%
df=pd.read_csv("diabetic_data.csv")

# %%
df.drop(['encounter_id','patient_nbr','weight','payer_code','medical_specialty'], axis=1, inplace=True)

# %%
# Here is a simple function to show descriptive stats on the categorical variables
def describe_categorical(X):
    """
    Just like .describe(), but returns the results for
    categorical variables only.
    """
    from IPython.display import display, HTML
    display(HTML(X[X.columns[X.dtypes == "object"]].describe().to_html()))

# %%
# Get just the numeric variables by selecting only the variables that are not "object" datatypes.
numeric_variables = list(df.dtypes[df.dtypes != "object"].index)
df[numeric_variables].head()
# Out:
#    admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                  6                        25                    1
# 1                  1                         1                    7
# 2                  1                         1                    7
# 3                  1                         1                    7
# 4                  1                         1                    7
#
#    time_in_hospital  num_lab_procedures  num_procedures  num_medications  \
# 0                 1                  41               0                1
# 1                 3                  59               0               18
# 2                 2                  11               5               13
# 3                 2                  44               1               16
# 4                 1                  51               0                8
#
#    number_outpatient  number_emergency  number_inpatient  number_diagnoses
# ...

# %%
# Look at all the columns in the dataset
def printall(X, max_rows=10):
    from IPython.display import display, HTML
    display(HTML(X.to_html(max_rows=max_rows)))
    
printall(df)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>race</th>
#       <th>gender</th>
#       <th>age</th>
#       <th>admission_type_id</th>
#       <th>discharge_disposition_id</th>
#       <th>admission_source_id</th>
#       <th>time_in_hospital</th>
#       <th>num_lab_procedures</th>
#       <th>num_procedures</th>
#       <th>num_medications</th>
#       <th>number_outpatient</th>
#       <th>number_emergency</th>
#       <th>number_inpatient</th>
#       <th>diag_1</th>
#       <th>diag_2</th>
#       <th>diag_3</th>
#       <th>number_diagnoses</th>
#       <th>max_glu_serum</th>
#       <th>A1Cresult</th>
#       <th>metformin</th>
#       <th>repaglinide</th>
#       <th>nateglinide</th>
#       <th>chlorpropamide</th>
#       <th>glimepiride</th>
#       <th>acetohexamide</th>
#       <th>glipizide</th>
#       <th>glyburide</th>
#       <th>tolbutamide</th>
#       <th>pioglitazone</th>
# ...

# %%
admission_type = {1:'Emergency',
2:'Urgent',
3:'Elective',
4:'Newborn',
5:'NA',
6:'NULL',
7:'TraumaCenter',
8:'NotMapped',
}
df.admission_type_id =df.admission_type_id.map(admission_type)

# %%
discharge_dispo = {1:'discharged_home',
2:'discharged_to_short_term_hospital',
3:'discharged_SNF',
4:'discharged_ICF',
5:'discharged_Inpatient_Care_Inst',
6:'discharged_home_w_health_service',
7:'left_AMA',
8:'discharged_home_w_IV provider',
9:'admitted_as_inpatient',
10:'Neonate_discharged_neonatal_aftercare',
11:'expired',
12:'will_return_as_outpatient',
13:'hospice_home',
14:'hospice_medical_facility',
15:'discharged_to_this_institution_for_medicare_swing_bed',
16:'discharged_another_institution_for_outpatient_services',
17:'discharged_for_outpatient_services',
18:'unknown',
19:'expired_at_home', 
20:'expired_at_medical_facility',
21:'expired_unknown_loc',
22:'discharged_rehab_fac',
23:'discharged_long_term_care',
24:'discharged_nursing_facility_Medicade',
25:'unknown',
26:'unknown',
30:'discharged_undefined_healthcare_inst',
27:'discharged_federal_facility',
28:'discharged_psychiatric',
29:'discharged_CAH'}

df.discharge_disposition_id =df.discharge_disposition_id.map(discharge_dispo)

# %%
admit_source = {
1:'physician',
2:'clinic',
3:'HMO',
4:'transfer_hospital',
5:'transfer_SNF',
6:'transfer_HCF',
7:'ER',
8:'court_LE',
9:'unknown',
10:'transfer_CAH',
11:'normal_delivery',
12:'premature_delivery',
13:'sick_baby',
14:'extramural_birth',
15:'unknown',
17:'unknown',
18:'transfer_HHA',
19:'readmission',
20:'unknown',
21:'unknown',
22:'transfer_same_fac',
23:'born_inside_hospital',
24:'born_outside_hospital',
25:'transfer_ambulatory_surgery',
26:'transfer_hospice'}

df.admission_source_id = df.admission_source_id.map(admit_source)
