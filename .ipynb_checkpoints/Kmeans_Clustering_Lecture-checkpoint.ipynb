# %% [markdown]
# This lecture was based on a fantastic blog, originally [located here](http://blog.revolutionanalytics.com/2013/12/k-means-clustering-86-single-malt-scotch-whiskies.html) by Luba Gloukhov

# %%
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# %matplotlib inline

# %%
df = pd.read_csv("whiskies.txt")

# %%
df.drop(['RowID'], inplace=True, axis=1)

# %%
remove_tab = lambda x: x.replace('\t','')
df.Postcode = df.Postcode.map(remove_tab)

# %%
df.head()
# Out:
#   Distillery  Body  Sweetness  Smoky  Medicinal  Tobacco  Honey  Spicy  Winey  \
# 0  Aberfeldy     2          2      2          0        0      2      1      2
# 1   Aberlour     3          3      1          0        0      4      3      2
# 2     AnCnoc     1          3      2          0        0      2      0      0
# 3     Ardbeg     4          1      4          4        0      0      2      0
# 4    Ardmore     2          2      2          0        0      1      1      1
#
#    Nutty  Malty  Fruity  Floral   Postcode   Latitude   Longitude
# 0      2      2       2       2   PH15 2EB     286580      749680
# 1      2      3       3       2   AB38 9PJ     326340      842570
# 2      2      2       3       2    AB5 5LI     352960      839320
# 3      1      2       1       0   PA42 7EB     141560      646220
# 4      2      3       1       1   AB54 4NH     355350      829140

# %%
X = df.drop(['Distillery','Postcode',' Latitude',' Longitude'], axis=1)

# %%
X.head()
# Out:
#    Body  Sweetness  Smoky  Medicinal  Tobacco  Honey  Spicy  Winey  Nutty  \
# 0     2          2      2          0        0      2      1      2      2
# 1     3          3      1          0        0      4      3      2      2
# 2     1          3      2          0        0      2      0      0      2
# 3     4          1      4          4        0      0      2      0      1
# 4     2          2      2          0        0      1      1      1      2
#
#    Malty  Fruity  Floral
# 0      2       2       2
# 1      3       3       2
# 2      2       3       2
# 3      2       1       0
# 4      3       1       1

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
# Out:
# /home/mike/.conda/envs/oldnb/lib/python2.7/site-packages/sklearn/utils/validation.py:332: UserWarning: StandardScaler assumes floating point values as input, got int64
#   "got %s" % (estimator, X.dtype))

# %%
kmeans_model = KMeans(n_clusters=4, random_state=42)
kmeans_model.fit(X_scaled)
# Out:
# KMeans(copy_x=True, init='k-means++', max_iter=300, n_clusters=4, n_init=10,
#     n_jobs=1, precompute_distances=True, random_state=42, tol=0.0001,
#     verbose=0)

# %%
df['labels'] = kmeans_model.labels_

# %%
df.head()
# Out:
#   Distillery  Body  Sweetness  Smoky  Medicinal  Tobacco  Honey  Spicy  Winey  \
# 0  Aberfeldy     2          2      2          0        0      2      1      2
# 1   Aberlour     3          3      1          0        0      4      3      2
# 2     AnCnoc     1          3      2          0        0      2      0      0
# 3     Ardbeg     4          1      4          4        0      0      2      0
# 4    Ardmore     2          2      2          0        0      1      1      1
#
#    Nutty  Malty  Fruity  Floral   Postcode   Latitude   Longitude  labels
# 0      2      2       2       2   PH15 2EB     286580      749680       0
# 1      2      3       3       2   AB38 9PJ     326340      842570       0
# 2      2      2       3       2    AB5 5LI     352960      839320       1
# 3      1      2       1       0   PA42 7EB     141560      646220       2
# 4      2      3       1       1   AB54 4NH     355350      829140       3

# %%
df[df['labels'] == 2]
# Out:
#    Distillery  Body  Sweetness  Smoky  Medicinal  Tobacco  Honey  Spicy  \
# 3      Ardbeg     4          1      4          4        0      0      2
# 21   Caol Ila     3          1      4          2        1      0      2
# 23  Clynelish     3          2      3          3        1      0      2
# 57  Lagavulin     4          1      4          4        1      0      1
# 58   Laphroig     4          2      4          4        1      0      0
# 77   Talisker     4          2      3          3        0      1      3
#
#     Winey  Nutty  Malty  Fruity  Floral   Postcode   Latitude   Longitude  \
# 3       0      1      2       1       0   PA42 7EB     141560      646220
# 21      0      2      1       1       1   PA46 7RL     142920      670040
# 23      0      1      1       2       0    KW9 6LB     290250      904230
# 57      2      1      1       1       0   PA42 7DZ     140430      645730
# 58      1      1      1       0       0   PA42 7DU     138680      645160
# 77      0      1      2       2       0   IV47 8SR     137950      831770
#
#     labels
# 3        2
# 21       2
# 23       2
# 57       2
# 58       2
# 77       2

# %%
from sklearn.manifold import TSNE
model = TSNE(n_components=3, learning_rate=12)
X_tsne = model.fit_transform(X)

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
ax = plt.subplot(111, projection='3d')
ax.scatter(X_tsne[:, 0], X_tsne[:, 1],X_tsne[:,2], c=kmeans_model.labels_)
